# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import os
from IPython.display import display

pd.set_option('display.max_columns',50)
pd.set_option('display.max_rows',10)
pd.set_option('display.float_format',lambda x: '%.2f' %x)

# 加载数据
def load_data():
    '''智能加载医保数据'''
    data_file = Path('D:\下载\食管癌数据\out_put\访视(住院就诊).csv')
    
    if not data_file.exists():
        data_file = Path('D:\下载\食管癌数据\out_put\访视(住院就诊).csv')

        if not data_file.exists():
            raise FileNotFoundError('cannot find the data file')
        
    try:
        df = pd.read_csv(data_file)
    except UnicodeDecodeError:
        try:
            df = pd.read_csv(data_file, encoding= 'GBK')
        except:
            df = pd.read_csv(data_file, encoding= ' latin1')
    
    return df

print('加载医保数据')
df = load_data()
print(f'加载完成,总记录数为:{len(df):,}')

# display(df.head(2)) 显示黄色波浪线通常是因为 Jupyter Notebook 没有自动导入 display 函数。
# 解决方法：从 IPython.display 导入 display
display(df.head(2))

# df.describe().T
# Out:
# <>:16: SyntaxWarning: invalid escape sequence '\o'
# <>:19: SyntaxWarning: invalid escape sequence '\o'
# <>:16: SyntaxWarning: invalid escape sequence '\o'
# <>:19: SyntaxWarning: invalid escape sequence '\o'
# C:\Users\DYL93\AppData\Local\Temp\ipykernel_8676\1322096244.py:16: SyntaxWarning: invalid escape sequence '\o'
#   data_file = Path('D:\下载\食管癌数据\out_put\访视(住院就诊).csv')
# C:\Users\DYL93\AppData\Local\Temp\ipykernel_8676\1322096244.py:19: SyntaxWarning: invalid escape sequence '\o'
#   data_file = Path('D:\下载\食管癌数据\out_put\访视(住院就诊).csv')
# 加载医保数据
# ...
